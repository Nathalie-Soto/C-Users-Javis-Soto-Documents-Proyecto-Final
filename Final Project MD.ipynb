# %% [markdown]
# # Proyecto web scraper ZARA-NIKE-CRUZ AZUL

# %%
# Librerías a utilizar:
import pandas as pd
import pandasql as ps
#from urllib.request import urlopen
#import urllib.request
#import requests
import time 
import numpy as np
import re
from selenium import webdriver
import matplotlib.pyplot as plt
#from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ## Requeremientos

# %%
## instalacion de web driver 
## instalacion de selenium y pandas sql

# %% [markdown]
# ### Definiciones

# %%
# tag html: Una etiqueta HTML es una pieza de lenguaje de marcado que se utiliza para indicar el principio y el final 
#           de un elemento HTML en un documento HTML. Como parte de un elemento HTML, las etiquetas HTML ayudan 
#           a los navegadores web a convertir documentos HTML en páginas web.


# class html: La clase es un atributo que especifica uno o más nombres de clase para un elemento HTML. El atributo de clase 
#             se puede utilizar en cualquier elemento HTML. CSS y JavaScript pueden usar el nombre de clase para realizar 
#             ciertas tareas para elementos con el nombre de clase especificado

# %% [markdown]
# # ZARA

# %%
aux=pd.DataFrame()
aux.to_excel("df_zara.xlsx",index=False)

# %%
def Buscador_Precios_Selenium_zara(producto):
    """
    Función que hace WEB SCRAPPING EN LA PÁGINA DE ZARA
    """
    ### ingresamos a la pagina web 
    path = "C:\webdriver3\chromedriver.exe"
    #path = mipath
    driver=webdriver.Chrome(path)
    url = "https://www.zara.com/mx/es/search?searchTerm="+producto+"&section=WOMAN"
    driver.get(url)
    
    ####### Accedemos a los elementos que contienen los datos que queremos de la pagina web 
    

    productos= driver.find_elements_by_class_name("product-grid-product__info-wrapper")
    
    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### accedemos a los nombres de los productos

    lista_nombres=list()
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[0].text)
        except:
            lista_nombres.append(np.nan)
            
            
    ### accedemos a los precios base y promo de los productos 

    lista_precios=list()
    lista_promos=list()
    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("price-current__amount")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("price-old__amount")[0].text)
        except:
            lista_promos.append(np.nan)





    df_zara =pd.DataFrame({"nombre":lista_nombres,"url":lista_urls,"precio1":lista_promos,"precio2":lista_precios})
    df_zara["Tienda"]="ZARA"
    df_zara["marca"]= producto
    df_zara["fecha"]= time.strftime("%d/%m/%y")

    df_zara = df_zara[["fecha","Tienda","marca","nombre","url","precio1","precio2"]]
    ## este filtro apenas se agrega

    #df_zara = df_zara[df_zara['nombre'].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_zara  = df_zara.reset_index(drop=True)



    datos_webscraper=pd.read_excel("df_zara.xlsx")

    datos_webscraper= pd.concat([datos_webscraper,df_zara],axis=0)

    datos_webscraper.to_excel("df_zara.xlsx",index=False)

    driver.quit()
    return df_zara

# %%
# Se aplica la función anterior a los siguientes productos:
for productos in ["chamarra","playera","gorra"]:
    Buscador_Precios_Selenium_zara(productos)
# Out:
# <ipython-input-5-8427f6b13757>:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)
# <ipython-input-5-8427f6b13757>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   productos= driver.find_elements_by_class_name("product-grid-product__info-wrapper")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:464: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
df_zara=pd.read_excel("df_zara.xlsx")
df_zara.head()
# Out:
#       fecha Tienda     marca                        nombre  \
# 0  28/01/22   ZARA  chamarra  BLAZER CRUZADA PATA DE GALLO
# 1  28/01/22   ZARA  chamarra     BLAZER CROPPED ESTRUCTURA
# 2  28/01/22   ZARA  chamarra            BLAZER EFECTO PIEL
# 3  28/01/22   ZARA  chamarra                 BLAZER FLUIDA
# 4  28/01/22   ZARA  chamarra       BLAZER CRUZADA OVERSIZE
#
#                                                  url precio1       precio2
# 0  https://www.zara.com/mx/es/blazer-cruzada-pata...     NaN  1.599,00 MXN
# 1  https://www.zara.com/mx/es/blazer-cropped-estr...     NaN  1.299,00 MXN
# 2  https://www.zara.com/mx/es/blazer-efecto-piel-...     NaN  1.599,00 MXN
# 3  https://www.zara.com/mx/es/blazer-fluida-p0125...     NaN  1.299,00 MXN
# 4  https://www.zara.com/mx/es/blazer-cruzada-over...     NaN  1.299,00 MXN

# %%
# Limpiando precios
for precio in ['precio1','precio2']:
    df_zara[precio] = df_zara[precio].str.replace(" MXN","")
    df_zara[precio] = df_zara[precio].str.replace(".","")
    df_zara[precio] = df_zara[precio].str.replace(",",".")
    df_zara[precio] = df_zara[precio].astype(float)

# %%
ps.sqldf("select  * from df_zara where (marca = 'chamarra') limit 5")
# Out:
#       fecha Tienda     marca                        nombre  \
# 0  28/01/22   ZARA  chamarra  BLAZER CRUZADA PATA DE GALLO
# 1  28/01/22   ZARA  chamarra     BLAZER CROPPED ESTRUCTURA
# 2  28/01/22   ZARA  chamarra            BLAZER EFECTO PIEL
# 3  28/01/22   ZARA  chamarra                 BLAZER FLUIDA
# 4  28/01/22   ZARA  chamarra       BLAZER CRUZADA OVERSIZE
#
#                                                  url precio1  precio2
# 0  https://www.zara.com/mx/es/blazer-cruzada-pata...    None   1599.0
# 1  https://www.zara.com/mx/es/blazer-cropped-estr...    None   1299.0
# 2  https://www.zara.com/mx/es/blazer-efecto-piel-...    None   1599.0
# 3  https://www.zara.com/mx/es/blazer-fluida-p0125...    None   1299.0
# 4  https://www.zara.com/mx/es/blazer-cruzada-over...    None   1299.0

# %%
ps.sqldf("select marca, url from df_zara where (marca = 'gorra') limit 10 ")
# Out:
#    marca                                                url
# 0  gorra  https://www.zara.com/mx/es/gorra-tipo-marinero...
# 1  gorra  https://www.zara.com/mx/es/sombrero-fieltro-p0...
# 2  gorra  https://www.zara.com/mx/es/boina-lana-p0373921...
# 3  gorra  https://www.zara.com/mx/es/beanie-punto-p03739...
# 4  gorra  https://www.zara.com/mx/es/beanie-punto-p00653...
# 5  gorra  https://www.zara.com/mx/es/beanie-punto-p03739...
# 6  gorra  https://www.zara.com/mx/es/beanie-punto-p03739...
# 7  gorra  https://www.zara.com/mx/es/boina-lana-p0373921...
# 8  gorra  https://www.zara.com/mx/es/beanie-punto-p03739...
# 9  gorra  https://www.zara.com/mx/es/sombrero-fieltro-p0...

# %%
ps.sqldf("select count(*) from df_zara where (marca = 'gorra') ")
# Out:
#    count(*)
# 0        19

# %%
ps.sqldf("select count(*) from df_zara where precio1 is null")
# Out:
#    count(*)
# 0        53

# %%
ps.sqldf("select count(*) from df_zara where (marca= 'playera') ")
# Out:
#    count(*)
# 0         8

# %%
ps.sqldf("select marca,avg(precio2) as preciopromedio from df_zara group by marca ")
# Out:
#       marca  preciopromedio
# 0  chamarra     1589.000000
# 1     gorra      403.736842
# 2   playera      444.000000

# %%
ps.sqldf("select count(*)  from df_zara where precio1 is not null ")
# Out:
#    count(*)
# 0         4

# %%
ps.sqldf("select *  from df_zara where precio1 <10000 or precio2<10000 limit 5")
# Out:
#       fecha Tienda     marca                        nombre  \
# 0  28/01/22   ZARA  chamarra  BLAZER CRUZADA PATA DE GALLO
# 1  28/01/22   ZARA  chamarra     BLAZER CROPPED ESTRUCTURA
# 2  28/01/22   ZARA  chamarra            BLAZER EFECTO PIEL
# 3  28/01/22   ZARA  chamarra                 BLAZER FLUIDA
# 4  28/01/22   ZARA  chamarra       BLAZER CRUZADA OVERSIZE
#
#                                                  url precio1  precio2
# 0  https://www.zara.com/mx/es/blazer-cruzada-pata...    None   1599.0
# 1  https://www.zara.com/mx/es/blazer-cropped-estr...    None   1299.0
# 2  https://www.zara.com/mx/es/blazer-efecto-piel-...    None   1599.0
# 3  https://www.zara.com/mx/es/blazer-fluida-p0125...    None   1299.0
# 4  https://www.zara.com/mx/es/blazer-cruzada-over...    None   1299.0

# %%
# Ditribución de precios

for i in ["chamarra","playera","gorra"]:
    plt.figure(figsize=(10,10))
    plt.hist(df_zara[df_zara['marca']==i]["precio2"])
    plt.title("Dsitribución de precios: " +str(i)+"Tienda ZARA")
    plt.show()

# %% [markdown]
# # NIKE

# %%
aux=pd.DataFrame()
aux.to_excel("df_nike.xlsx",index=False)

# %%
def Buscador_Precios_Selenium_nike(producto):
    """
    Función que hace WEB SCRAPPING EN LA PÁGINA DE NIKE
    """
  ### ingresamos a la pagina web 
    path = "C:\webdriver3\chromedriver.exe"
    #path= mipath
    driver=webdriver.Chrome(path)
    url= "https://www.nike.com/mx/w?q="+producto+"&vst="+producto
    driver.get(url)
    
    
    ####### Accedemos a los elementos que contienen los datos que queremos de la pagina web 
    

    productos= driver.find_elements_by_class_name("product-card__body")
    
    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### accedemos a los nombres de los productos

    lista_nombres=list()
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_class_name("product-card__subtitle")[0].text)
        except:
            lista_nombres.append(np.nan)
            
            
    ### accedemos a los precios base y promo de los productos 

    lista_precios=list()
    lista_promos=list()
    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("product-price")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("product-price")[1].text)
        except:
            lista_promos.append(np.nan)





    df_nike =pd.DataFrame({"nombre":lista_nombres,"url":lista_urls,"precio1":lista_promos,"precio2":lista_precios})
    df_nike["Tienda"]="Nike"
    df_nike["marca"]= producto
    df_nike["fecha"]= time.strftime("%d/%m/%y")

    df_nike = df_nike[["fecha","Tienda","marca","nombre","url","precio1","precio2"]]
    ## este filtro apenas se agrega

    #df_soriana = df_soriana[df_soriana['nombre'].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_nike  = df_nike.reset_index(drop=True)



    datos_webscraper=pd.read_excel("df_nike.xlsx")

    datos_webscraper= pd.concat([datos_webscraper,df_nike],axis=0)

    datos_webscraper.to_excel("df_nike.xlsx",index=False)

    driver.quit()
    return df_nike

# %%
# Se aplica la función anterior a los siguientes productos:
for productos in ["playera","gorra","chamarra"]:
    Buscador_Precios_Selenium_nike(productos)
# Out:
# <ipython-input-19-0397f9d9a9ba>:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)
# <ipython-input-19-0397f9d9a9ba>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   productos= driver.find_elements_by_class_name("product-card__body")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:464: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
df_nike=pd.read_excel("df_nike.xlsx")
df_nike
# Out:
#        fecha Tienda     marca  \
# 0   28/01/22   Nike   playera
# 1   28/01/22   Nike   playera
# 2   28/01/22   Nike   playera
# 3   28/01/22   Nike   playera
# 4   28/01/22   Nike   playera
# ..       ...    ...       ...
# 65  28/01/22   Nike  chamarra
# 66  28/01/22   Nike  chamarra
# 67  28/01/22   Nike  chamarra
# 68  28/01/22   Nike  chamarra
# 69  28/01/22   Nike  chamarra
#
#                                                nombre  \
# 0   Sudadera con gorro sin cierre de tejido Fleece...
# 1       Playera de running de manga corta para hombre
# 2   Camiseta de tirantes de entrenamiento para hombre
# 3                           Polo de tenis para hombre
# 4                Sudadera de entrenamiento para mujer
# ..                                                ...
# 65                                  Parka para hombre
# 66            Chamarra universitaria Nike para hombre
# 67              Chamarra bomber con forro para hombre
# 68                     Chamarra con gorro para hombre
# 69                      Chamarra acolchada para mujer
#
#                                                   url precio1 precio2
# 0   https://www.nike.com/mx/t/sudadera-con-gorro-s...     NaN  $1,549
# 1   https://www.nike.com/mx/t/playera-de-running-d...     NaN    $799
# 2   https://www.nike.com/mx/t/camiseta-de-tirantes...     NaN    $699
# 3   https://www.nike.com/mx/t/polo-de-tenis-court-...     NaN    $849
# 4   https://www.nike.com/mx/t/sudadera-de-entrenam...     NaN  $1,249
# ..                                                ...     ...     ...
# 65  https://www.nike.com/mx/t/parka-sportswear-the...     NaN  $2,749
# 66  https://www.nike.com/mx/t/chamarra-universitar...     NaN  $2,749
# 67  https://www.nike.com/mx/t/chamarra-bomber-con-...     NaN  $2,899
# 68  https://www.nike.com/mx/t/chamarra-con-gorro-s...  $2,399  $1,919
# 69  https://www.nike.com/mx/t/chamarra-acolchada-j...  $3,399  $2,719
#
# [70 rows x 7 columns]

# %%
# Limpiando precios
for precio in ['precio1','precio2']:
    df_nike[precio] = df_nike[precio].str.replace("$","")
    df_nike[precio] = df_nike[precio].str.replace(",",".")
    df_nike[precio] = df_nike[precio].astype(float)

# %%
ps.sqldf("select  * from df_nike where (marca = 'chamarra') limit 5")
# Out:
#       fecha Tienda     marca  \
# 0  28/01/22   Nike  chamarra
# 1  28/01/22   Nike  chamarra
# 2  28/01/22   Nike  chamarra
# 3  28/01/22   Nike  chamarra
# 4  28/01/22   Nike  chamarra
#
#                                               nombre  \
# 0                     Chamarra de running para mujer
# 1                               Chamarra para hombre
# 2              Chamarra de calentamiento para hombre
# 3                                Camiseta para mujer
# 4  Chamarra de cierre completo de tejido Fleece p...
#
#                                                  url precio1  precio2
# 0  https://www.nike.com/mx/t/chamarra-de-running-...    None    5.499
# 1  https://www.nike.com/mx/t/chamarra-jordan-jump...    None    1.899
# 2  https://www.nike.com/mx/t/chamarra-de-calentam...    None    2.299
# 3  https://www.nike.com/mx/t/chamarra-jordan-new-...    None    2.749
# 4  https://www.nike.com/mx/t/chamarra-de-cierre-c...    None    2.749

# %%
ps.sqldf("select count(*) from df_nike where (marca= 'playera') ")
# Out:
#    count(*)
# 0        24

# %%
ps.sqldf("select marca, url from df_nike where (marca = 'gorra') limit 10 ")
# Out:
#    marca                                                url
# 0  gorra  https://www.nike.com/mx/t/gorro-sportswear-her...
# 1  gorra  https://www.nike.com/mx/t/gorra-de-golf-dri-fi...
# 2  gorra  https://www.nike.com/mx/t/gorra-con-cierre-a-p...
# 3  gorra  https://www.nike.com/mx/t/gorra-de-running-per...
# 4  gorra  https://www.nike.com/mx/t/gorra-fc-barcelona-h...
# 5  gorra  https://www.nike.com/mx/t/gorra-ajustable-aero...
# 6  gorra  https://www.nike.com/mx/t/gorra-de-running-aer...
# 7  gorra  https://www.nike.com/mx/t/gorra-giannis-herita...
# 8  gorra  https://www.nike.com/mx/t/gorro-ajustable-pro-...
# 9  gorra  https://www.nike.com/mx/t/gorra-prelavada-jord...

# %%
ps.sqldf("select count(*) from df_nike where (marca = 'gorra') ")
# Out:
#    count(*)
# 0        22

# %%
ps.sqldf("select count(*) from df_nike where precio1 is null")
# Out:
#    count(*)
# 0        66

# %%
ps.sqldf("select marca,avg(precio2) as preciopromedio from df_nike group by marca ")
# Out:
#       marca  preciopromedio
# 0  chamarra        2.638167
# 1     gorra      514.909091
# 2   playera      449.974583

# %%
ps.sqldf("select count(*)  from df_nike where precio1 is not null ")
# Out:
#    count(*)
# 0         4

# %%
ps.sqldf("select *  from df_nike where precio1 <10000 or precio2<10000 limit 5")
# Out:
#       fecha Tienda    marca  \
# 0  28/01/22   Nike  playera
# 1  28/01/22   Nike  playera
# 2  28/01/22   Nike  playera
# 3  28/01/22   Nike  playera
# 4  28/01/22   Nike  playera
#
#                                               nombre  \
# 0  Sudadera con gorro sin cierre de tejido Fleece...
# 1      Playera de running de manga corta para hombre
# 2  Camiseta de tirantes de entrenamiento para hombre
# 3                          Polo de tenis para hombre
# 4               Sudadera de entrenamiento para mujer
#
#                                                  url precio1  precio2
# 0  https://www.nike.com/mx/t/sudadera-con-gorro-s...    None    1.549
# 1  https://www.nike.com/mx/t/playera-de-running-d...    None  799.000
# 2  https://www.nike.com/mx/t/camiseta-de-tirantes...    None  699.000
# 3  https://www.nike.com/mx/t/polo-de-tenis-court-...    None  849.000
# 4  https://www.nike.com/mx/t/sudadera-de-entrenam...    None    1.249

# %%
# Ditribución de precios

for i in ["playera","gorra","chamarra"]:
    plt.figure(figsize=(10,10))
    plt.hist(df_nike[df_nike['marca']==i]["precio2"])
    plt.title("Dsitribución de precios: " +str(i)+"Tienda Nike")
    plt.show()

# %% [markdown]
# # CRUZ AZUL

# %%
aux=pd.DataFrame()
aux.to_excel("df_cruz_azul.xlsx",index=False)

# %%
def Buscador_Precios_Selenium_cruz_azul(producto):
    """
    Función que hace WEB SCRAPPING EN LA PÁGINA DE CRUZ AZUL
    """
    ### ingresamos a la pagina web 
    path ="C:\webdriver3\chromedriver.exe"
    driver=webdriver.Chrome(path)
    url = "https://www.tiendacruzazul.mx/catalogsearch/result/?q="+producto
    driver.get(url)
    
    ####### Accedemos a los elementos que contienen los datos que queremos de la pagina web 
    

    productos= driver.find_elements_by_class_name("product-item-info")
    
    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### accedemos a los nombres de los productos

    lista_nombres=list()
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[1].text)
        except:
            lista_nombres.append(np.nan)
            
            
    ### accedemos a los precios base y promo de los productos 

    lista_precios=list()
    lista_promos=list()
    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("price")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("price")[1].text)
        except:
            lista_promos.append(np.nan)





    df_cruz_azul =pd.DataFrame({"nombre":lista_nombres,"url":lista_urls,"precio1":lista_promos,"precio2":lista_precios})
    df_cruz_azul["Tienda"]="Cruz Azul"
    df_cruz_azul["marca"]= producto
    df_cruz_azul["fecha"]= time.strftime("%d/%m/%y")

    df_cruz_azul = df_cruz_azul[["fecha","Tienda","marca","nombre","url","precio1","precio2"]]
    ## este filtro apenas se agrega

    #df_soriana = df_soriana[df_soriana['nombre'].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_cruz_azul = df_cruz_azul.reset_index(drop=True)



    datos_webscraper=pd.read_excel("df_cruz_azul.xlsx")

    datos_webscraper= pd.concat([datos_webscraper,df_cruz_azul],axis=0)

    datos_webscraper.to_excel("df_cruz_azul.xlsx",index=False)

    driver.quit()
    return df_cruz_azul

# %%
# Se aplica la función anterior a los siguientes productos:
for productos in ["gorra","playera","chamarra"]:
    Buscador_Precios_Selenium_cruz_azul(productos)
# Out:
# <ipython-input-33-c9eb0f183c1d>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)
# <ipython-input-33-c9eb0f183c1d>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   productos= driver.find_elements_by_class_name("product-item-info")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# C:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:464: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
df_cruz_azul=pd.read_excel("df_cruz_azul.xlsx")
df_cruz_azul
# Out:
#        fecha     Tienda     marca  \
# 0   28/01/22  Cruz Azul     gorra
# 1   28/01/22  Cruz Azul     gorra
# 2   28/01/22  Cruz Azul     gorra
# 3   28/01/22  Cruz Azul     gorra
# 4   28/01/22  Cruz Azul     gorra
# 5   28/01/22  Cruz Azul   playera
# 6   28/01/22  Cruz Azul   playera
# 7   28/01/22  Cruz Azul   playera
# 8   28/01/22  Cruz Azul   playera
# 9   28/01/22  Cruz Azul   playera
# 10  28/01/22  Cruz Azul   playera
# 11  28/01/22  Cruz Azul   playera
# 12  28/01/22  Cruz Azul   playera
# 13  28/01/22  Cruz Azul   playera
# 14  28/01/22  Cruz Azul   playera
# 15  28/01/22  Cruz Azul   playera
# 16  28/01/22  Cruz Azul   playera
# 17  28/01/22  Cruz Azul  chamarra
# 18  28/01/22  Cruz Azul  chamarra
# 19  28/01/22  Cruz Azul  chamarra
# 20  28/01/22  Cruz Azul  chamarra
#
#                                                nombre  \
# 0         GORRA EDICIÓN LIMITADA CRUZ AZUL " CAMPEÓN"
# 1     940 GORRA CRUZ AZUL HEXTECH ROYAL"NEW ERA" ADJ.
# 2   3930 GORRA CRUZ AZUL RETRO BRIGHT ROYAL "NEW ERA"
# 3       950SS GORRA HEXTECH BLUE CRUZ AZUL "NEW ERA".
# 4      3030 GORRA CRUZ AZUL ENGINEERED GRAY "NEW ERA"
# 5             Jersey Portero Magenta M/L C-19 "NIÑO".
# 6       JERSEY EDICIÓN ESPECIAL MANGA LARGA CABALLERO
# 7      JERSEY EDICIÓN ESPECIAL MANGA CORTA CABALLERO.
# 8           JERSEY EDICIÓN ESPECIAL MANGA CORTA DAMA.
# 9           JERSEY EDICIÓN ESPECIAL MANGA CORTA NIÑO.
# 10               Jersey Alterno Cruz Azul Mujer 21-22
# 11                     JERSEY ALTERNATIVO 20-21 MUJER
# 12                          JERSEY VISITA 20-21 MUJER
# 13                           JERSEY LOCAL 20-21 MUJER
# 14                            JERSEY LOCAL 20-21 NIÑO
# 15                         Jersey Visita Mujer T19-20
# 16                     Jersey Alternativo Niño T19-20
# 17  Chamarra Con Cierre Completo Royal Cruz Azul 2...
# 18  Chamarra Cierre Completo Marino Cruz Azul 21-2...
# 19  Chamarra Chandal Cruz Azul Caballero 21-22 Azu...
# 20          Chamarra Anorak Cruz Azul Caballero 21-22
#
#                                                   url  precio1    precio2
# 0   https://www.tiendacruzazul.mx/940-lmx-clucruhm...      NaN    $999.00
# 1   https://www.tiendacruzazul.mx/940-gorra-cruz-a...      NaN    $599.00
# 2   https://www.tiendacruzazul.mx/3930-gorra-cruz-...      NaN    $699.00
# 3   https://www.tiendacruzazul.mx/950ss-gorra-hext...      NaN    $749.00
# 4   https://www.tiendacruzazul.mx/3030-gorra-cruz-...      NaN    $699.00
# 5   https://www.tiendacruzazul.mx/jersey-portero-m...      NaN    $350.00
# 6   https://www.tiendacruzazul.mx/jersey-edicion-e...      NaN  $1,699.00
# 7   https://www.tiendacruzazul.mx/jersey-edicion-e...      NaN  $1,399.00
# 8   https://www.tiendacruzazul.mx/jersey-edicion-e...      NaN  $1,399.00
# 9   https://www.tiendacruzazul.mx/jersey-edicion-e...      NaN  $1,349.00
# 10  https://www.tiendacruzazul.mx/jersey-alterno-c...      NaN  $1,299.00
# 11  https://www.tiendacruzazul.mx/jersey-alternati...      NaN    $779.50
# 12  https://www.tiendacruzazul.mx/jersey-visita-20...      NaN    $779.50
# 13  https://www.tiendacruzazul.mx/jersey-local-20-...      NaN    $779.50
# 14  https://www.tiendacruzazul.mx/jersey-local-20-...      NaN  $1,249.00
# 15  https://www.tiendacruzazul.mx/jersey-visita-mu...      NaN    $349.00
# 16  https://www.tiendacruzazul.mx/jersey-alternati...      NaN    $349.00
# 17  https://www.tiendacruzazul.mx/chamarra-con-cie...      NaN    $999.00
# 18  https://www.tiendacruzazul.mx/chamarra-cierre-...      NaN    $999.00
# 19  https://www.tiendacruzazul.mx/chamarra-anorak-...      NaN  $1,299.00
# 20  https://www.tiendacruzazul.mx/chamarra-anorak-...      NaN  $1,999.00

# %%
# Limpiando precios
for precio in ['precio2']:
    df_cruz_azul[precio] = df_cruz_azul[precio].str.replace("$","")
    df_cruz_azul[precio] = df_cruz_azul[precio].str.replace(",","")
    df_cruz_azul[precio] = df_cruz_azul[precio].astype(float)

# %%
ps.sqldf("select  * from df_cruz_azul where (marca = 'chamarra') limit 5")
# Out:
#       fecha     Tienda     marca  \
# 0  28/01/22  Cruz Azul  chamarra
# 1  28/01/22  Cruz Azul  chamarra
# 2  28/01/22  Cruz Azul  chamarra
# 3  28/01/22  Cruz Azul  chamarra
#
#                                               nombre  \
# 0  Chamarra Con Cierre Completo Royal Cruz Azul 2...
# 1  Chamarra Cierre Completo Marino Cruz Azul 21-2...
# 2  Chamarra Chandal Cruz Azul Caballero 21-22 Azu...
# 3          Chamarra Anorak Cruz Azul Caballero 21-22
#
#                                                  url precio1  precio2
# 0  https://www.tiendacruzazul.mx/chamarra-con-cie...    None    999.0
# 1  https://www.tiendacruzazul.mx/chamarra-cierre-...    None    999.0
# 2  https://www.tiendacruzazul.mx/chamarra-anorak-...    None   1299.0
# 3  https://www.tiendacruzazul.mx/chamarra-anorak-...    None   1999.0

# %%
ps.sqldf("select marca, url from df_cruz_azul where (marca = 'gorra') ")
# Out:
#    marca                                                url
# 0  gorra  https://www.tiendacruzazul.mx/940-lmx-clucruhm...
# 1  gorra  https://www.tiendacruzazul.mx/940-gorra-cruz-a...
# 2  gorra  https://www.tiendacruzazul.mx/3930-gorra-cruz-...
# 3  gorra  https://www.tiendacruzazul.mx/950ss-gorra-hext...
# 4  gorra  https://www.tiendacruzazul.mx/3030-gorra-cruz-...

# %%
ps.sqldf("select count(*) from df_cruz_azul where (marca = 'gorra') ")
# Out:
#    count(*)
# 0         5

# %%
ps.sqldf("select count(*) from df_cruz_azul where precio1 is null")
# Out:
#    count(*)
# 0        21

# %%
ps.sqldf("select count(*) from df_cruz_azul where (marca= 'playera') ")
# Out:
#    count(*)
# 0        12

# %%
ps.sqldf("select marca,avg(precio2) as preciopromedio from df_cruz_azul group by marca ")
# Out:
#       marca  preciopromedio
# 0  chamarra     1324.000000
# 1     gorra      749.000000
# 2   playera      981.708333

# %%
ps.sqldf("select count(*)  from df_cruz_azul where precio2 is not null ")
# Out:
#    count(*)
# 0        21

# %%
ps.sqldf("select *  from df_cruz_azul where precio1 <10000 or precio2<10000 limit 5")
# Out:
#       fecha     Tienda  marca  \
# 0  28/01/22  Cruz Azul  gorra
# 1  28/01/22  Cruz Azul  gorra
# 2  28/01/22  Cruz Azul  gorra
# 3  28/01/22  Cruz Azul  gorra
# 4  28/01/22  Cruz Azul  gorra
#
#                                               nombre  \
# 0        GORRA EDICIÓN LIMITADA CRUZ AZUL " CAMPEÓN"
# 1    940 GORRA CRUZ AZUL HEXTECH ROYAL"NEW ERA" ADJ.
# 2  3930 GORRA CRUZ AZUL RETRO BRIGHT ROYAL "NEW ERA"
# 3      950SS GORRA HEXTECH BLUE CRUZ AZUL "NEW ERA".
# 4     3030 GORRA CRUZ AZUL ENGINEERED GRAY "NEW ERA"
#
#                                                  url precio1  precio2
# 0  https://www.tiendacruzazul.mx/940-lmx-clucruhm...    None    999.0
# 1  https://www.tiendacruzazul.mx/940-gorra-cruz-a...    None    599.0
# 2  https://www.tiendacruzazul.mx/3930-gorra-cruz-...    None    699.0
# 3  https://www.tiendacruzazul.mx/950ss-gorra-hext...    None    749.0
# 4  https://www.tiendacruzazul.mx/3030-gorra-cruz-...    None    699.0

# %%
# Ditribución de precios

for i in ["gorra","playera","chamarra"]:
    plt.figure(figsize=(10,10))
    plt.hist(df_cruz_azul[df_cruz_azul['marca']==i]["precio2"])
    plt.title("Dsitribución de precios: " +str(i)+"Tienda Cruz Azul")
    plt.show()
